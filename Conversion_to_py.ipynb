# %%
import ee
import geemap

# %%
js_snippet = """ 
// precipitation plot ROI

//var country =ee.FeatureCollection('USDOS/LSIB/2013');
//var CO= country.filter(ee.Filter.eq('cc', 'CO'));
var region = 'Magdalena';
var country =ee.FeatureCollection("FAO/GAUL/2015/level1");

var CO= country.filter(ee.Filter.eq('ADM1_NAME', region));
print (CO);

var dataset = ee.ImageCollection('TRMM/3B43V7')
                  .filter(ee.Filter.date('1998-01-01', '2019-12-31'));
var precipitation = dataset.select('precipitation');
var precipitationVis = {min:0.15, max:0.26,
  palette: ['yellow','purple','blue'],
};
Map.centerObject(CO,8);
print(Estaciones)
//Estaciones = Estaciones.filter(ee.Filter.eq('CLASE', 'MET')).filter(ee.Filter.eq('ESTADO', 'ACT'))
var prec_col = precipitation.reduce((ee.Reducer.median())).clip(CO);
print(prec_col)

Map.addLayer(prec_col, precipitationVis, 'Precipitación');
//Map.addLayer(Estaciones.draw({color:'black', pointRadius: 1}),{},'Estaciones Ideam')
// Define a region of interest as a buffer around a point.
//var geom = ee.Geometry.Point(Centro).buffer(500);

// Create and print the chart.
//var mean_prec_chart = ui.Chart.image.series(precipitation, Centro);
var mean_prec_chart = ui.Chart.image.series(precipitation, CO, ee.Reducer.mean());
mean_prec_chart.setChartType('ColumnChart');
mean_prec_chart.setOptions({title:'Precipitación TRMM Mensual para '+region,
  vAxis: {
    title: 'Precipitación mm/hora'
  },
  hAxis: {
    title: 'Mes del año'
  },
});
print(mean_prec_chart);

//print(ui.Chart.image.series;


//print(ui.Chart.image.histogram(precipitation;

// Create the legend.
// Define a panel for the legend and give it a tile.
// set position of panel
var legend = ui.Panel({
  style: {
    position: 'bottom-center',
    padding: '8px 15px'
  }
});
 
// Create legend title
var legendTitle = ui.Label({
  value: 'Leyenda',
  style: {
    fontWeight: 'bold',
    fontSize: '18px',
    margin: '0 0 4px 0',
    padding: '0'
    }
});
 
// Add the title to the panel
legend.add(legendTitle);
 
// Creates and styles 1 row of the legend.
var makeRow = function(color, name) {
 
      // Create the label that is actually the colored box.
      var colorBox = ui.Label({
        style: {
          backgroundColor: '#' + color,
          // Use padding to give the box height and width.
          padding: '8px',
          margin: '0 0 0px 0'
        }
      });
 
      // Create the label filled with the description text.
      var description = ui.Label({
        value: name,
        style: {margin: '0 0 4px 6px'}
      });
 
      // return the panel
      return ui.Panel({
        widgets: [colorBox, description],
        layout: ui.Panel.Layout.Flow('horizontal')
      });
};
 
//  Palette with the colors
var palette =['1500ff', '800080', 'FFFF00'];
 
// name of the legend
var names = ['Precipitación alta','Precipitación moderada','Precipitación baja'];
 
// Add color and and names
for (var i = 0; i < 3; i++) {
  legend.add(makeRow(palette[i], names[i]));
  }  
 
// add legend to map (alternatively you can also print the legend to the console)
Map.add(legend); """

# %%
geemap.js_snippet_to_py( js_snippet, add_new_cell=True, import_ee=True, import_geemap=True, show_map=True)
# Out:
# 'utf-8' codec can't decode byte 0xf3 in position 858: invalid continuation byte
